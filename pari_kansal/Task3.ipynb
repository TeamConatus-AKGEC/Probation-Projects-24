# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data =pd.read_csv(r"C:\Users\Sarvesh\Downloads\DataClean - DataClean.csv.csv")
data.columns
# Out:
# Index(['Unnamed: 0', 'brand', 'model', 'transmission', 'age', 'fuel', 'engine',
#        'Distance', 'owner', 'price', 'location', 'mileage', 'power', 'seats',
#        'type'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data =pd.read_csv(r"C:\Users\Sarvesh\Downloads\DataClean - DataClean.csv.csv")
data.columns
data.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine           8132
# Distance            0
# owner           15381
# price               0
# location        18399
# mileage         10820
# power           10927
# seats            2847
# type            24185
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data =pd.read_csv(r"C:\Users\Sarvesh\Downloads\DataClean - DataClean.csv.csv")
data.columns
data.isnull().sum()
data.drop(columns=['type'])
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance  owner    price       location  mileage  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv(r"C:\Users\Sarvesh\Downloads\DataClean - DataClean.csv.csv")
df = pd.DataFrame(data)
print(data.columns)
print(data.isnull().sum())
data.drop(columns=['type'])
missing_vals = ["NA", "", None, np.nan]
missing = data.isin(missing_vals)
print(missing.head())
df.drop(df.columns[df.columns.str.contains('Unnamed',case=False)],axis=1,inplace=True)
df
# Out:
# Index(['Unnamed: 0', 'brand', 'model', 'transmission', 'age', 'fuel', 'engine',
#        'Distance', 'owner', 'price', 'location', 'mileage', 'power', 'seats',
#        'type'],
#       dtype='object')
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine           8132
# Distance            0
# owner           15381
# price               0
# location        18399
# mileage         10820
# power           10927
# seats            2847
# type            24185
# dtype: int64
#    Unnamed: 0  brand  model  transmission    age   fuel  engine  Distance  \
# 0       False  False  False         False  False  False    True     False
# 1       False  False  False         False  False  False   False     False
# 2       False  False  False         False  False  False   False     False
# 3       False  False  False         False  False  False   False     False
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"C:\Users\Sarvesh\Downloads\DataClean - DataClean.csv.csv")
df = pd.DataFrame(data)
df.drop(df.columns[df.columns.str.contains('Unnamed',case=False)],axis=1,inplace=True)
df
plt.figure(figsize=(15,8))
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(),annot = True,cmap="YlGnBu")
plt.show()
df.drop_duplicates(inplace=True)

# %%
missing_rows = df[df.isnull().any(axis=1)]
print(missing_rows)
# Out:
#                brand       model transmission   age    fuel  engine  \
# 0         volkswagen        ameo       manual   8.0  diesel     NaN
# 1            renault      duster       manual   8.0  diesel  1461.0
# 2               land       rover    automatic  21.0  diesel  1197.0
# 3      mercedes-benz         new    automatic  10.0  diesel  2143.0
# 4             maruti        alto       manual   4.0     cng     NaN
# ...              ...         ...          ...   ...     ...     ...
# 32195        hyundai      santro       manual  15.0  petrol  1086.0
# 32196     volkswagen       vento       manual   8.0  petrol  1598.0
# 32197            bmw           5    automatic   8.0  diesel  1995.0
# 32198        hyundai  new santro       manual   3.0  petrol     NaN
# 32199          honda        city       manual   9.0  petrol  1497.0
#
#                 Distance  owner    price       location  mileage   power  \
# 0             52858.0 KM    1.0   876000  uttar pradesh      NaN     NaN
# ...

# %%
max_nans_allowed = 5
deleted_rows = df[df.isnull().sum(axis=1) > max_nans_allowed]
cleaned_df = df.dropna(thresh=len(df.columns) - max_nans_allowed)
print(deleted_rows)
# Out:
#          brand   model transmission  age    fuel  engine           Distance  \
# 223        kia   sonet       manual  2.0  diesel     NaN         28326.0 KM
# 386      skoda   rapid       manual  8.0  petrol     NaN         65970.0 KM
# 566     datsun    redi    automatic  4.0  petrol     NaN         23581.0 KM
# 704       tata   nexon    automatic  1.0  petrol     NaN         12971.0 KM
# 921    renault  duster       manual  9.0  diesel     NaN         94510.0 KM
# ...        ...     ...          ...  ...     ...     ...                ...
# 29968   maruti    alto       manual  8.0  petrol     NaN         45310.0 KM
# 30386  renault    kwid    automatic  5.0  petrol     NaN         24558.0 KM
# 30676       mg  hector       manual  4.0  diesel     NaN  12098000.0 Meters
# 30702   maruti     new    automatic  2.0  petrol     NaN          9301.0 KM
# 31485    honda   amaze       manual  6.0     cng     NaN  73050000.0 Meters
#
# ...

# %%
max_nans_allowed = 5
cleaned_df = df.dropna(thresh=len(df.columns) - max_nans_allowed)
print(cleaned_df)
# Out:
#                brand       model transmission   age    fuel  engine  \
# 0         volkswagen        ameo       manual   8.0  diesel     NaN
# 1            renault      duster       manual   8.0  diesel  1461.0
# 2               land       rover    automatic  21.0  diesel  1197.0
# 3      mercedes-benz         new    automatic  10.0  diesel  2143.0
# 4             maruti        alto       manual   4.0     cng     NaN
# ...              ...         ...          ...   ...     ...     ...
# 32195        hyundai      santro       manual  15.0  petrol  1086.0
# 32196     volkswagen       vento       manual   8.0  petrol  1598.0
# 32197            bmw           5    automatic   8.0  diesel  1995.0
# 32198        hyundai  new santro       manual   3.0  petrol     NaN
# 32199          honda        city       manual   9.0  petrol  1497.0
#
#                 Distance  owner    price       location  mileage   power  \
# 0             52858.0 KM    1.0   876000  uttar pradesh      NaN     NaN
# ...

# %%
def convert_to_km(row):
    value,unit =row.split()
    value =float(value)
    if unit =='Metres':
        return value*0.001
    elif unit =='Miles':
        return value*1.60934
    else:
        return value
    df['Distance_KM']=df['Distance'].apply(convert_to_km)
    df=df.drop(columns=['distance'])
    df

# %%
nan_values_in_Age = df[df['age'].isnull()]
print(nan_values_in_Age)
# Out:
#      brand model transmission  age    fuel  engine  owner   price location  \
# 1817   NaN   NaN    automatic  NaN  petrol     NaN    1.0  976000    delhi
#
#       mileage  power  seats   type  Distance_KM
# 1817      NaN    NaN    5.0  sedan      13794.0

# %%
df.drop(index=1817)
# Out:
#                brand       model transmission   age    fuel  engine  owner  \
# 0         volkswagen        ameo       manual   8.0  diesel     NaN    1.0
# 1            renault      duster       manual   8.0  diesel  1461.0    NaN
# 2               land       rover    automatic  21.0  diesel  1197.0    2.0
# 3      mercedes-benz         new    automatic  10.0  diesel  2143.0    1.0
# 4             maruti        alto       manual   4.0     cng     NaN    1.0
# ...              ...         ...          ...   ...     ...     ...    ...
# 32195        hyundai      santro       manual  15.0  petrol  1086.0    2.0
# 32196     volkswagen       vento       manual   8.0  petrol  1598.0    NaN
# 32197            bmw           5    automatic   8.0  diesel  1995.0    NaN
# 32198        hyundai  new santro       manual   3.0  petrol     NaN    1.0
# 32199          honda        city       manual   9.0  petrol  1497.0    NaN
#
# ...

# %%
missing_in_engine= df['engine'].isnull()
print(missing_in_engine)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 32195    False
# 32196    False
# 32197    False
# 32198     True
# 32199    False
# Name: engine, Length: 32044, dtype: bool

# %%
#as enine is mostly ralated to power
if engine & power == 'NaN':
    df.drop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 #as enine is mostly ralated to power
# ----> 2 if engine & power == 'NaN':
#       3     df.drop()
#
# NameError: name 'engine' is not defined

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
print("Categorical columns (object type):", categorical_columns)
# Out:
# Categorical columns (object type): Index(['brand', 'model', 'transmission', 'fuel', 'location', 'type'], dtype='object')

# %%
owner=plt.hist(df['owner'],bins=1000)

# %%
#plt.figure(figsize=(10, 6))
import matplotlib.pyplot as plt
plt.scatter(data['Distance'], data['owner'], alpha=0.6)
x = np.arange(0, 32000, 1000)

# %%
min_value = data['Distance'].min()
max_value = data['Distance'].max()
value_range = max_value - min_value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 3
#       1 min_value = data['Distance'].min()
#       2 max_value = data['Distance'].max()
# ----> 3 value_range = max_value - min_value
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
print(data['Distance'].dtype)
#data['Distance'] = pd.to_numeric(data['Distance'], errors='coerce')
min_value = data['Distance'].min()
max_value = data['Distance'].max()
value_range = max_value - min_value
print(value_range)
# Out:
# float64
# nan

# %%
df_cleaned = df.drop_duplicates()
