# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
price=[3543536,658654,456756,879432,85468]
year=[2021,2022,2023,2024,2025]
plt.plot(year,price)
plt.title("Price rate in market")
plt.xlabel("Year")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=[10,20,30,40,50,38,79,35,28,90,45,78,69,30,27,18,49,90]
y=[2,4,6,8,10,3,5,7,9,1,2,5,9,4,0,3,9,5]
plt.scatter(x,y)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
children=[20,30,5,38,18]
colors=['red','blue','yellow','green','black']
plt.bar(colors,children)
# Out:
# <BarContainer object of 5 artists>

# %%
import matplotlib.pyplot as plt
col=[8000,12000,9800,11200,7300]
section= ['A','B,'C','D','E'] 
         plt.title("WEEK collection")
         plt.axis("equal")
         plt.pie(col,labels=section,autopct="%5.2f%%")
         plt.show()
